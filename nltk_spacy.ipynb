# %%
# Make sure both python executable location and 
# pip3 packages' installed location are same
import sys
# python executable location (mostly sym links)
print(sys.executable) 

# !which pip3
# !ls -l /usr/local/bin/python3

# pip3 should point to the same location as python3
# !pip3 -V

# If the output is like the below, then you are fine!!
# /usr/local/bin/python3
# /usr/local/bin/pip3
# lrwxr-xr-x  1 root  wheel  70 Nov 10 21:30 /usr/local/bin/python3 -> ../../../Library/Frameworks/Python.framework/Versions/3.14/bin/python3
# pip 26.0.1 from /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pip (python 3.14)ArithmeticError
# Out:
# /usr/local/bin/python3
# /usr/local/bin/pip3
# lrwxr-xr-x  1 root  wheel  70 Nov 10 21:30 /usr/local/bin/python3 -> ../../../Library/Frameworks/Python.framework/Versions/3.14/bin/python3
# pip 26.0.1 from /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pip (python 3.14)

# %%
# Install libraries
import sys

# Natural Language TookKit
# !pip3 install nltk
# !pip3 install spacy
# Out:
# /usr/local/bin/python3: No module named pip3
# /usr/local/bin/python3: No module named pip3

# %%
# Get spacy version
# !pip3 show spacy | grep Version
# Out:
# Version: 3.8.11
# Location: /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages

# %%
# Get NLTK version
# !pip3 show nltk | grep Version
# Out:
# Version: 3.9.3
# License: Apache License, Version 2.0
# Location: /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages

# %%
# import the library
import nltk

# %%
text = "Dave relocated to Paris last year to pursue his passion. his currently enrolled in a comprehensive course on language processing."
text
# Out:
# 'Dave relocated to Paris last year to pursue his passion. his currently enrolled in a comprehensive course on language processing.'

# %%
# Download a pre-trained punkt tokenizer for English
# To execute these commands, root certificates are required
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /Users/shirley/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/shirley/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
# [nltk_data] Error loading punkt_tab: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1077)>

# If you get the above error, do the following on macbook
# This script(step 1) installs the Apple system certificate bundle for Python

# Step 1
# !open "/Applications/Python 3.14/Install Certificates.command"

# Step 2 - Restart VS Code

# Step 3 - Restart the notebook kernel

# Step 4 - Run again:

# %%
# Import a function word_tokenize from nltk.tokenize module
from nltk.tokenize import word_tokenize

# Break the sentence into words
tokens = word_tokenize (text)
print(tokens)
# tokens  # to display in multiple lines
# Out:
# ['Dave', 'relocated', 'to', 'Paris', 'last', 'year', 'to', 'pursue', 'his', 'passion', '.', 'his', 'currently', 'enrolled', 'in', 'a', 'comprehensive', 'course', 'on', 'language', 'processing', '.']

# %%
# Display stem for each word
# PorterStemmer is an algorithm used for stemming in English
from  nltk.stem import PorterStemmer
stemmer = PorterStemmer()

# Apply stemming on each word in the token list
stemmed_words = [stemmer.stem(token) for token in tokens]
print(stemmed_words)

# stemmed_words # to display in multiple lines
# Out:
# ['dave', 'reloc', 'to', 'pari', 'last', 'year', 'to', 'pursu', 'hi', 'passion', '.', 'hi', 'current', 'enrol', 'in', 'a', 'comprehens', 'cours', 'on', 'languag', 'process', '.']

# %%
# Part-of-speech tagging to determine the verbs, nouns, etc.,
from nltk import pos_tag

# pos_tag internally loads Perception POS tagging model
# so install the dataset
nltk.download('averaged_perceptron_tagger_eng')

text_pos_tag = pos_tag(tokens)
print(text_pos_tag)
text_pos_tag
# Out:
# [('Dave', 'NNP'), ('relocated', 'VBD'), ('to', 'TO'), ('Paris', 'NNP'), ('last', 'JJ'), ('year', 'NN'), ('to', 'TO'), ('pursue', 'VB'), ('his', 'PRP$'), ('passion', 'NN'), ('.', '.'), ('his', 'PRP$'), ('currently', 'RB'), ('enrolled', 'VBN'), ('in', 'IN'), ('a', 'DT'), ('comprehensive', 'JJ'), ('course', 'NN'), ('on', 'IN'), ('language', 'NN'), ('processing', 'NN'), ('.', '.')]
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/shirley/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [('Dave', 'NNP'),
#  ('relocated', 'VBD'),
#  ('to', 'TO'),
#  ('Paris', 'NNP'),
#  ('last', 'JJ'),
#  ('year', 'NN'),
#  ('to', 'TO'),
#  ('pursue', 'VB'),
#  ('his', 'PRP$'),
#  ('passion', 'NN'),
#  ('.', '.'),
#  ('his', 'PRP$'),
#  ('currently', 'RB'),
#  ('enrolled', 'VBN'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('comprehensive', 'JJ'),
#  ('course', 'NN'),
#  ('on', 'IN'),
#  ('language', 'NN'),
#  ('processing', 'NN'),
#  ('.', '.')]

# %%
# Install resource tageset_json
nltk.download('tagsets_json')

# Display the label for each tag 
nltk.help.upenn_tagset("NNP")
# Out:
# NNP: noun, proper, singular
#     Motown Venneboerger Czestochwa Ranzer Conchita Trumplane Christos
#     Oceanside Escobar Kreisler Sawyer Cougar Yvette Ervin ODI Darryl CTCA
#     Shannon A.K.C. Meltex Liverpool ...
# [nltk_data] Downloading package tagsets_json to
# [nltk_data]     /Users/shirley/nltk_data...
# [nltk_data]   Package tagsets_json is already up-to-date!

# %%
# Named Entity Recognition (NER)
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')

# Differentiate Dave(Person) from Paris(location)
entities = nltk.ne_chunk(text_pos_tag)
print(entities) # now Dave & Paris are recognised
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /Users/shirley/nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# [nltk_data] Downloading package words to /Users/shirley/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# (S
#   (PERSON Dave/NNP)
#   relocated/VBD
#   to/TO
#   (GPE Paris/NNP)
#   last/JJ
#   year/NN
#   to/TO
#   pursue/VB
#   his/PRP$
#   passion/NN
#   ./.
#   his/PRP$
#   currently/RB
#   enrolled/VBN
#   in/IN
#   a/DT
#   comprehensive/JJ
#   course/NN
#   on/IN
#   language/NN
#   processing/NN
#   ./.)

# %%
# SpaCy 3.x officially supports Python 3.7–3.11.
# !pip3 install --upgrade pip
# !pip3 install "spacy<4.0" --force-reinstall

import spacy
# Ensure you have this model downloaded
# !python -m spacy download en_core_web_lg

# Load the English Language pipeline for optimizing CPU performance
# Pre-trained word embedding
nlp = spacy.load('en_core_web_lg')

# Word embeddings are a type of word representation where words 
# are mapped to vectors allowing words with similar meaning to 
# have a similar representation

# Process words with the model
word1 = nlp("king")
word2 = nlp("queen")
word3 = nlp("apple")

# Calculate the similarities(or word embeddings)
similarity1 = word1.similarity(word2)
similarity2 = word1.similarity(word3)

# Display the similarities
print(f"Similarity between 'king' and 'queen': {similarity1:.2f}")
print(f"Similarity between 'king' and 'apple': {similarity2:.2f}")

# King & Queen woudl show higher similarity due to its contextual closeness
# Out:
# Requirement already satisfied: pip in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (26.0.1)
# Collecting spacy<4.0
#   Using cached spacy-3.8.11-cp314-cp314-macosx_11_0_arm64.whl.metadata (27 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy<4.0)
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy<4.0)
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy<4.0)
#   Using cached murmurhash-1.0.15-cp314-cp314-macosx_11_0_arm64.whl.metadata (2.3 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy<4.0)
#   Using cached cymem-2.0.13-cp314-cp314-macosx_11_0_arm64.whl.metadata (9.7 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy<4.0)
#   Using cached preshed-3.0.12-cp314-cp314-macosx_11_0_arm64.whl.metadata (2.5 kB)
# Collecting thinc<8.4.0,>=8.3.4 (from spacy<4.0)
#   Using cached thinc-8.3.10-cp314-cp314-macosx_11_0_arm64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy<4.0)
#   Using cached wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy<4.0)
#   Using cached srsly-2.5.2-cp314-cp314-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy<4.0)
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.4.2 (from spacy<4.0)
#   Using cached weasel-0.4.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting typer-slim<1.0.0,>=0.3.0 (from spacy<4.0)
#   Using cached typer_slim-0.24.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting tqdm<5.0.0,>=4.38.0 (from spacy<4.0)
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting numpy>=1.19.0 (from spacy<4.0)
#   Using cached numpy-2.4.3-cp314-cp314-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Collecting requests<3.0.0,>=2.13.0 (from spacy<4.0)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 (from spacy<4.0)
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting jinja2 (from spacy<4.0)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting setuptools (from spacy<4.0)
#   Using cached setuptools-82.0.1-py3-none-any.whl.metadata (6.5 kB)
# Collecting packaging>=20.0 (from spacy<4.0)
#   Using cached packaging-26.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0)
#   Using cached pydantic_core-2.41.5-cp314-cp314-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Collecting typing-extensions>=4.14.1 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3.0.0,>=2.13.0->spacy<4.0)
#   Using cached charset_normalizer-3.4.5-cp314-cp314-macosx_10_15_universal2.whl.metadata (39 kB)
# Collecting idna<4,>=2.5 (from requests<3.0.0,>=2.13.0->spacy<4.0)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0.0,>=2.13.0->spacy<4.0)
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2017.4.17 (from requests<3.0.0,>=2.13.0->spacy<4.0)
#   Using cached certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.4->spacy<4.0)
#   Using cached blis-1.3.3-cp314-cp314-macosx_11_0_arm64.whl.metadata (7.5 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.4.0,>=8.3.4->spacy<4.0)
#   Using cached confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Collecting typer>=0.24.0 (from typer-slim<1.0.0,>=0.3.0->spacy<4.0)
#   Using cached typer-0.24.1-py3-none-any.whl.metadata (16 kB)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.4.2->spacy<4.0)
#   Using cached cloudpathlib-0.23.0-py3-none-any.whl.metadata (16 kB)
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel<0.5.0,>=0.4.2->spacy<4.0)
#   Using cached smart_open-7.5.1-py3-none-any.whl.metadata (24 kB)
# Collecting wrapt (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy<4.0)
#   Using cached wrapt-2.1.2-cp314-cp314-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Collecting click>=8.2.1 (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy<4.0)
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy<4.0)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=12.3.0 (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy<4.0)
#   Using cached rich-14.3.3-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy<4.0)
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy<4.0)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting pygments<3.0.0,>=2.13.0 (from rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy<4.0)
#   Using cached pygments-2.19.2-py3-none-any.whl.metadata (2.5 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy<4.0)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->spacy<4.0)
#   Using cached markupsafe-3.0.3-cp314-cp314-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Using cached spacy-3.8.11-cp314-cp314-macosx_11_0_arm64.whl (5.7 MB)
# Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Using cached cymem-2.0.13-cp314-cp314-macosx_11_0_arm64.whl (42 kB)
# Using cached murmurhash-1.0.15-cp314-cp314-macosx_11_0_arm64.whl (27 kB)
# Using cached preshed-3.0.12-cp314-cp314-macosx_11_0_arm64.whl (123 kB)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached pydantic_core-2.41.5-cp314-cp314-macosx_11_0_arm64.whl (1.9 MB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.5-cp314-cp314-macosx_10_15_universal2.whl (280 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Using cached spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Using cached srsly-2.5.2-cp314-cp314-macosx_11_0_arm64.whl (655 kB)
# Using cached thinc-8.3.10-cp314-cp314-macosx_11_0_arm64.whl (740 kB)
# Using cached blis-1.3.3-cp314-cp314-macosx_11_0_arm64.whl (1.2 MB)
# Using cached confection-0.1.5-py3-none-any.whl (35 kB)
# Using cached numpy-2.4.3-cp314-cp314-macosx_14_0_arm64.whl (5.2 MB)
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Using cached typer_slim-0.24.0-py3-none-any.whl (3.4 kB)
# Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Using cached wasabi-1.1.3-py3-none-any.whl (27 kB)
# Using cached weasel-0.4.3-py3-none-any.whl (50 kB)
# Using cached cloudpathlib-0.23.0-py3-none-any.whl (62 kB)
# Using cached smart_open-7.5.1-py3-none-any.whl (64 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached certifi-2026.2.25-py3-none-any.whl (153 kB)
# Using cached packaging-26.0-py3-none-any.whl (74 kB)
# Using cached typer-0.24.1-py3-none-any.whl (56 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Using cached rich-14.3.3-py3-none-any.whl (310 kB)
# Using cached pygments-2.19.2-py3-none-any.whl (1.2 MB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached markupsafe-3.0.3-cp314-cp314-macosx_11_0_arm64.whl (12 kB)
# Using cached setuptools-82.0.1-py3-none-any.whl (1.0 MB)
# Using cached wrapt-2.1.2-cp314-cp314-macosx_11_0_arm64.whl (61 kB)
# Installing collected packages: wrapt, wasabi, urllib3, typing-extensions, tqdm, spacy-loggers, spacy-legacy, shellingham, setuptools, pygments, packaging, numpy, murmurhash, mdurl, MarkupSafe, idna, cymem, cloudpathlib, click, charset_normalizer, certifi, catalogue, annotated-types, annotated-doc, typing-inspection, srsly, smart-open, requests, pydantic-core, preshed, markdown-it-py, jinja2, blis, rich, pydantic, typer, confection, typer-slim, thinc, weasel, spacy
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 2.1.2
#     Uninstalling wrapt-2.1.2:
#       Successfully uninstalled wrapt-2.1.2
#   Attempting uninstall: wasabi
#     Found existing installation: wasabi 1.1.3
#     Uninstalling wasabi-1.1.3:
#       Successfully uninstalled wasabi-1.1.3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.6.3
#     Uninstalling urllib3-2.6.3:
#       Successfully uninstalled urllib3-2.6.3
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.15.0
#     Uninstalling typing_extensions-4.15.0:
#       Successfully uninstalled typing_extensions-4.15.0━━━━━━━━━━━  3/41 [typing-extensions]
#   Attempting uninstall: tqdm━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/41 [typing-extensions]
#     Found existing installation: tqdm 4.67.3━━━━━━━━━━━━━━━━━━  3/41 [typing-extensions]
#     Uninstalling tqdm-4.67.3:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/41 [typing-extensions]
#       Successfully uninstalled tqdm-4.67.3━━━━━━━━━━━━━━━━━━━━  3/41 [typing-extensions]
#   Attempting uninstall: spacy-loggers━━━━━━━━━━━━━━━━━━━━━━━━━  3/41 [typing-extensions]
#     Found existing installation: spacy-loggers 1.0.5━━━━━━━━━━  3/41 [typing-extensions]
#     Uninstalling spacy-loggers-1.0.5:━━━━━━━━━━━━━━━━━━━━━━━━━  3/41 [typing-extensions]
#       Successfully uninstalled spacy-loggers-1.0.5━━━━━━━━━━━━  3/41 [typing-extensions]
#   Attempting uninstall: spacy-legacy━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/41 [spacy-loggers]
#     Found existing installation: spacy-legacy 3.0.12━━━━━━━━━━  5/41 [spacy-loggers]
#     Uninstalling spacy-legacy-3.0.12:━━━━━━━━━━━━━━━━━━━━━━━━━  5/41 [spacy-loggers]
#       Successfully uninstalled spacy-legacy-3.0.12━━━━━━━━━━━━  5/41 [spacy-loggers]
#   Attempting uninstall: shellingham━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/41 [spacy-loggers]
#     Found existing installation: shellingham 1.5.4━━━━━━━━━━━━  5/41 [spacy-loggers]
#     Uninstalling shellingham-1.5.4:━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/41 [spacy-loggers]
#       Successfully uninstalled shellingham-1.5.4━━━━━━━━━━━━━━  5/41 [spacy-loggers]
#   Attempting uninstall: setuptools━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/41 [spacy-loggers]
#     Found existing installation: setuptools 82.0.1━━━━━━━━━━━━  5/41 [spacy-loggers]
#     Uninstalling setuptools-82.0.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/41 [spacy-loggers]
#       Successfully uninstalled setuptools-82.0.1━━━━━━━━━━━━━━  5/41 [spacy-loggers]
#   Attempting uninstall: pygments0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  8/41 [setuptools]
#     Found existing installation: Pygments 2.19.2━━━━━━━━━━━━━━  8/41 [setuptools]
#     Uninstalling Pygments-2.19.2:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  8/41 [setuptools]
#       Successfully uninstalled Pygments-2.19.2━━━━━━━━━━━━━━━━  8/41 [setuptools]
#   Attempting uninstall: packaging0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  9/41 [pygments]
#     Found existing installation: packaging 26.0━━━━━━━━━━━━━━━  9/41 [pygments]
#     Uninstalling packaging-26.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  9/41 [pygments]
#       Successfully uninstalled packaging-26.0━━━━━━━━━━━━━━━━━  9/41 [pygments]
#   Attempting uninstall: numpy0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  9/41 [pygments]
#     Found existing installation: numpy 2.4.3━━━━━━━━━━━━━━━━━━  9/41 [pygments]
#     Uninstalling numpy-2.4.3:0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  9/41 [pygments]
#       Successfully uninstalled numpy-2.4.3━━━━━━━━━━━━━━━━━━━━━━━━ 11/41 [numpy]
#   Attempting uninstall: murmurhash90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/41 [numpy]
#     Found existing installation: murmurhash 1.0.15━━━━━━━━━━━━ 11/41 [numpy]
#     Uninstalling murmurhash-1.0.15:━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/41 [numpy]
#       Successfully uninstalled murmurhash-1.0.15━━━━━━━━━━━━━━ 11/41 [numpy]
#   Attempting uninstall: mdurl━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/41 [numpy]
#     Found existing installation: mdurl 0.1.2━━━━━━━━━━━━━━━━━━ 11/41 [numpy]
#     Uninstalling mdurl-0.1.2:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/41 [numpy]
#       Successfully uninstalled mdurl-0.1.2━━━━━━━━━━━━━━━━━━━━ 11/41 [numpy]
#   Attempting uninstall: MarkupSafe━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/41 [numpy]
#     Found existing installation: MarkupSafe 3.0.3━━━━━━━━━━━━━ 11/41 [numpy]
#     Uninstalling MarkupSafe-3.0.3:━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/41 [numpy]
#       Successfully uninstalled MarkupSafe-3.0.3━━━━━━━━━━━━━━━ 11/41 [numpy]
#   Attempting uninstall: idna━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/41 [numpy]
#     Found existing installation: idna 3.11━━━━━━━━━━━━━━━━━━━━ 11/41 [numpy]
#     Uninstalling idna-3.11:m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/41 [numpy]
#       Successfully uninstalled idna-3.11━━━━━━━━━━━━━━━━━━━━━━ 11/41 [numpy]
#   Attempting uninstall: cymem━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/41 [numpy]
#     Found existing installation: cymem 2.0.13━━━━━━━━━━━━━━━━━ 11/41 [numpy]
#     Uninstalling cymem-2.0.13:90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/41 [numpy]
#       Successfully uninstalled cymem-2.0.13━━━━━━━━━━━━━━━━━━━ 11/41 [numpy]
#   Attempting uninstall: cloudpathlib━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/41 [numpy]
#     Found existing installation: cloudpathlib 0.23.0━━━━━━━━━━ 11/41 [numpy]
#     Uninstalling cloudpathlib-0.23.0:━━━━━━━━━━━━━━━━━━━━━━━━━ 11/41 [numpy]
#       Successfully uninstalled cloudpathlib-0.23.0━━━━━━━━━━━━ 11/41 [numpy]
#   Attempting uninstall: click╸━━━━━━━━━━━━━━━━━━━━━━━ 17/41 [cloudpathlib]
#     Found existing installation: click 8.3.1━━━━━━━━━━━━━━━━━━ 17/41 [cloudpathlib]
#     Uninstalling click-8.3.1:╸━━━━━━━━━━━━━━━━━━━━━━━ 17/41 [cloudpathlib]
#       Successfully uninstalled click-8.3.1━━━━━━━━━━━━━━━━━━━━ 17/41 [cloudpathlib]
#   Attempting uninstall: charset_normalizer━━━━━━━━━━━━━━━━━━━━ 17/41 [cloudpathlib]
#     Found existing installation: charset-normalizer 3.4.5━━━━━ 17/41 [cloudpathlib]
#     Uninstalling charset-normalizer-3.4.5:━━━━━━━━━━━━━━━━━━━━ 17/41 [cloudpathlib]
#       Successfully uninstalled charset-normalizer-3.4.5━━━━━━━━━━━ 19/41 [charset_normalizer]
#   Attempting uninstall: certifi╸━━━━━━━━━━━━━━━━━━━━━ 19/41 [charset_normalizer]
#     Found existing installation: certifi 2026.2.25━━━━━━━━━━━━ 19/41 [charset_normalizer]
#     Uninstalling certifi-2026.2.25:m━━━━━━━━━━━━━━━━━━━━━ 19/41 [charset_normalizer]
#       Successfully uninstalled certifi-2026.2.25━━━━━━━━━━━━━━ 19/41 [charset_normalizer]
#   Attempting uninstall: catalogue━━━━━━━━━━━━━━━━━━━━━ 19/41 [charset_normalizer]
#     Found existing installation: catalogue 2.0.10━━━━━━━━━━━━━ 19/41 [charset_normalizer]
#     Uninstalling catalogue-2.0.10:0m━━━━━━━━━━━━━━━━━━━━━ 19/41 [charset_normalizer]
#       Successfully uninstalled catalogue-2.0.10━━━━━━━━━━━━━━━ 19/41 [charset_normalizer]
#   Attempting uninstall: annotated-types0m━━━━━━━━━━━━━━━━━━━━━ 19/41 [charset_normalizer]
#     Found existing installation: annotated-types 0.7.0━━━━━━━━ 19/41 [charset_normalizer]
#     Uninstalling annotated-types-0.7.0:0m━━━━━━━━━━━━━━━━━━━━━ 19/41 [charset_normalizer]
#       Successfully uninstalled annotated-types-0.7.0━━━━━━━━━━ 19/41 [charset_normalizer]
#   Attempting uninstall: annotated-doc━━━━━━━━━━━━━━━━━━━━━ 19/41 [charset_normalizer]
#     Found existing installation: annotated-doc 0.0.4━━━━━━━━━━ 19/41 [charset_normalizer]
#     Uninstalling annotated-doc-0.0.4:━━━━━━━━━━━━━━━━━━━━━ 19/41 [charset_normalizer]
#       Successfully uninstalled annotated-doc-0.0.4━━━━━━━━━━━━ 19/41 [charset_normalizer]
#   Attempting uninstall: typing-inspection━━━━━━━━━━━━━━━━━━━━━ 19/41 [charset_normalizer]
#     Found existing installation: typing-inspection 0.4.2━━━━━━ 19/41 [charset_normalizer]
#     Uninstalling typing-inspection-0.4.2:━━━━━━━━━━━━━━━━━━━━━ 19/41 [charset_normalizer]
#       Successfully uninstalled typing-inspection-0.4.2━━━━━━━━ 19/41 [charset_normalizer]
#   Attempting uninstall: srsly1m╸━━━━━━━━━━━━━━━━━━━━━ 19/41 [charset_normalizer]
#     Found existing installation: srsly 2.5.2━━━━━━━━━━━━━━━━━━ 19/41 [charset_normalizer]
#     Uninstalling srsly-2.5.2:1m╸━━━━━━━━━━━━━━━━━━━━━ 19/41 [charset_normalizer]
#       Successfully uninstalled srsly-2.5.2━━━━━━━━━━━━━━━━━━━━ 19/41 [charset_normalizer]
#   Attempting uninstall: smart-open0m╺━━━━━━━━━━━━━━━ 25/41 [srsly]rmalizer]
#     Found existing installation: smart_open 7.5.1━━━━━━━━━━━━━ 25/41 [srsly]
#     Uninstalling smart_open-7.5.1:90m╺━━━━━━━━━━━━━━━ 25/41 [srsly]
#       Successfully uninstalled smart_open-7.5.1━━━━━━━━━━━━━━━ 25/41 [srsly]
#   Attempting uninstall: requests╺━━━━━━━━━━━━━━━ 25/41 [srsly]
#     Found existing installation: requests 2.32.5━━━━━━━━━━━━━━ 25/41 [srsly]
#     Uninstalling requests-2.32.5:╺━━━━━━━━━━━━━━━ 25/41 [srsly]
#       Successfully uninstalled requests-2.32.5m━━━━━━━━━━━━━━━ 25/41 [srsly]
#   Attempting uninstall: pydantic-core╺━━━━━━━━━━━━━━━ 25/41 [srsly]
#     Found existing installation: pydantic_core 2.41.5m━━━━━━━━━━━━ 28/41 [pydantic-core]
#     Uninstalling pydantic_core-2.41.5:0m╺━━━━━━━━━━━━ 28/41 [pydantic-core]
#       Successfully uninstalled pydantic_core-2.41.5━━━━━━━━━━━ 28/41 [pydantic-core]
#   Attempting uninstall: preshed╺━━━━━━━━━━━━ 28/41 [pydantic-core]
#     Found existing installation: preshed 3.0.1290m━━━━━━━━━━━━ 28/41 [pydantic-core]
#     Uninstalling preshed-3.0.12:╺━━━━━━━━━━━━ 28/41 [pydantic-core]
#       Successfully uninstalled preshed-3.0.12━━━━━━━━━━━━ 28/41 [pydantic-core]
#   Attempting uninstall: markdown-it-py0m╺━━━━━━━━━━━━ 28/41 [pydantic-core]
#     Found existing installation: markdown-it-py 4.0.0━━━━━━━━━ 28/41 [pydantic-core]
#     Uninstalling markdown-it-py-4.0.0:0m╺━━━━━━━━━━━━ 28/41 [pydantic-core]
#       Successfully uninstalled markdown-it-py-4.0.0━━━━━━━━━━━ 28/41 [pydantic-core]
#   Attempting uninstall: jinja2━╺━━━━━━━━━━━━ 28/41 [pydantic-core]
#     Found existing installation: Jinja2 3.1.6━━━━━━━━━━━━ 28/41 [pydantic-core]
#     Uninstalling Jinja2-3.1.6:━╺━━━━━━━━━━━━ 28/41 [pydantic-core]
#       Successfully uninstalled Jinja2-3.1.60m━━━━━━━━━━━━ 28/41 [pydantic-core]
#   Attempting uninstall: blis━━━━━━━━━━╺━━━━━━━━━ 31/41 [jinja2]re]
#     Found existing installation: blis 1.3.3╺━━━━━━━━━ 31/41 [jinja2]
#     Uninstalling blis-1.3.3:━━━━━━╺━━━━━━━━━ 31/41 [jinja2]
#       Successfully uninstalled blis-1.3.30m╺━━━━━━━━━ 31/41 [jinja2]
#   Attempting uninstall: rich━━━━━━╺━━━━━━━━━ 31/41 [jinja2]
#     Found existing installation: rich 14.3.3━━━━━━━━━ 31/41 [jinja2]
#     Uninstalling rich-14.3.3:━━━━━╺━━━━━━━━━ 31/41 [jinja2]
#       Successfully uninstalled rich-14.3.3m╺━━━━━━━━━ 31/41 [jinja2]
#   Attempting uninstall: pydantic━━━━━━━━╺━━━━━━━ 33/41 [rich]
#     Found existing installation: pydantic 2.12.50m━━━━━━━ 33/41 [rich]
#     Uninstalling pydantic-2.12.5:━━━╺━━━━━━━ 33/41 [rich]
#       Successfully uninstalled pydantic-2.12.5━━━━━━━ 33/41 [rich]
#   Attempting uninstall: typer━━━━━━━━━━━━╺━━━━━━ 34/41 [pydantic]
#     Found existing installation: typer 0.24.1m╺━━━━━━ 34/41 [pydantic]
#     Uninstalling typer-0.24.1:━━━━━━━╺━━━━━━ 34/41 [pydantic]
#       Successfully uninstalled typer-0.24.190m╺━━━━━━ 34/41 [pydantic]
#   Attempting uninstall: confection━━━━━━━━╺━━━━━ 35/41 [typer]
#     Found existing installation: confection 0.1.5━━━━━ 35/41 [typer]
#     Uninstalling confection-0.1.5:━━━━╺━━━━━ 35/41 [typer]
#       Successfully uninstalled confection-0.1.5╺━━━━━ 35/41 [typer]
#   Attempting uninstall: typer-slim━━━━╺━━━━━ 35/41 [typer]
#     Found existing installation: typer-slim 0.24.00m━━━━━ 35/41 [typer]
#     Uninstalling typer-slim-0.24.0:━━━╺━━━━━ 35/41 [typer]
#       Successfully uninstalled typer-slim-0.24.0━━━━━ 35/41 [typer]
#   Attempting uninstall: thinc━━━━━━━━━╺━━━━━ 35/41 [typer]
#     Found existing installation: thinc 8.3.100m╺━━━━━ 35/41 [typer]
#     Uninstalling thinc-8.3.10:━━━━━━━━╺━━━━━ 35/41 [typer]
#       Successfully uninstalled thinc-8.3.10╺━━━━━ 35/41 [typer]
#   Attempting uninstall: weasel━━━━━━━━━━━━━━━╺━━ 38/41 [thinc]
#     Found existing installation: weasel 0.4.3╺━━ 38/41 [thinc]
#     Uninstalling weasel-0.4.3:━━━━━━━━━━━╺━━ 38/41 [thinc]
#       Successfully uninstalled weasel-0.4.30m╺━━ 38/41 [thinc]
#   Attempting uninstall: spacy━━━━━━━━━━━━╺━━ 38/41 [thinc]
#     Found existing installation: spacy 3.8.11╺━━ 38/41 [thinc]
#     Uninstalling spacy-3.8.11:━━━━━━━━━━━━━━━━━╺ 40/41 [spacy]hinc]
#       Successfully uninstalled spacy-3.8.11╺ 40/41 [spacy]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41/41 [spacy]m [spacy]
# Successfully installed MarkupSafe-3.0.3 annotated-doc-0.0.4 annotated-types-0.7.0 blis-1.3.3 catalogue-2.0.10 certifi-2026.2.25 charset_normalizer-3.4.5 click-8.3.1 cloudpathlib-0.23.0 confection-0.1.5 cymem-2.0.13 idna-3.11 jinja2-3.1.6 markdown-it-py-4.0.0 mdurl-0.1.2 murmurhash-1.0.15 numpy-2.4.3 packaging-26.0 preshed-3.0.12 pydantic-2.12.5 pydantic-core-2.41.5 pygments-2.19.2 requests-2.32.5 rich-14.3.3 setuptools-82.0.1 shellingham-1.5.4 smart-open-7.5.1 spacy-3.8.11 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.2 thinc-8.3.10 tqdm-4.67.3 typer-0.24.1 typer-slim-0.24.0 typing-extensions-4.15.0 typing-inspection-0.4.2 urllib3-2.6.3 wasabi-1.1.3 weasel-0.4.3 wrapt-2.1.2
# ---------------------------------------------------------------------------
# ConfigError                               Traceback (most recent call last)
# Cell In[35], line 5
#       2 get_ipython().system('pip3 install --upgrade pip')
#       3 get_ipython().system('pip3 install "spacy<4.0" --force-reinstall')
# ----> 5 import spacy
#       6 # Ensure you have this model downloaded
#       7 get_ipython().system('python -m spacy download en_core_web_lg')
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/spacy/__init__.py:13
#      10 # These are imported as part of the API
#      11 from thinc.api import Config, prefer_gpu, require_cpu, require_gpu  # noqa: F401
# ---> 13 from . import pipeline  # noqa: F401
#      14 from . import util
#      15 from .about import __version__  # noqa: F401
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/spacy/pipeline/__init__.py:1
# ----> 1 from .attributeruler import AttributeRuler
#       2 from .dep_parser import DependencyParser
#       3 from .edit_tree_lemmatizer import EditTreeLemmatizer
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/spacy/pipeline/attributeruler.py:10
#       8 from .. import util
#       9 from ..errors import Errors
# ---> 10 from ..language import Language
#      11 from ..matcher import Matcher
#      12 from ..scorer import Scorer
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/spacy/language.py:46
#      44 from .lang.tokenizer_exceptions import BASE_EXCEPTIONS, URL_MATCH
#      45 from .lookups import load_lookups
# ---> 46 from .pipe_analysis import analyze_pipes, print_pipe_analysis, validate_attrs
#      47 from .schemas import (
#      48     ConfigSchema,
#      49     ConfigSchemaInit,
#    (...)     52     validate_init_settings,
#      53 )
#      54 from .scorer import Scorer
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/spacy/pipe_analysis.py:6
#       3 from wasabi import msg
#       5 from .errors import Errors
# ----> 6 from .tokens import Doc, Span, Token
#       7 from .util import dot_to_dict
#       9 if TYPE_CHECKING:
#      10     # This lets us add type hints for mypy etc. without causing circular imports
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/spacy/tokens/__init__.py:1
# ----> 1 from ._serialize import DocBin
#       2 from .doc import Doc
#       3 from .morphanalysis import MorphAnalysis
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/spacy/tokens/_serialize.py:14
#      12 from ..errors import Errors
#      13 from ..util import SimpleFrozenList, ensure_path
# ---> 14 from ..vocab import Vocab
#      15 from ._dict_proxies import SpanGroups
#      16 from .doc import DOCBIN_ALL_ATTRS as ALL_ATTRS
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/spacy/vocab.pyx:1, in init spacy.vocab()
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/spacy/tokens/doc.pyx:49, in init spacy.tokens.doc()
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/spacy/schemas.py:195
#     191         obj = converted
#     192     return validate(TokenPatternSchema, {"pattern": obj})
# --> 195 class TokenPatternString(BaseModel):
#     196     REGEX: Optional[Union[StrictStr, "TokenPatternString"]] = Field(None, alias="regex")
#     197     IN: Optional[List[StrictStr]] = Field(None, alias="in")
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pydantic/v1/main.py:221, in ModelMetaclass.__new__(mcs, name, bases, namespace, **kwargs)
#     219 elif is_valid_field(var_name) and var_name not in annotations and can_be_changed:
#     220     validate_field_name(bases, var_name)
# --> 221     inferred = ModelField.infer(
#     222         name=var_name,
#     223         value=value,
#     224         annotation=annotations.get(var_name, Undefined),
#     225         class_validators=vg.get_validators(var_name),
#     226         config=config,
#     227     )
#     228     if var_name in fields:
#     229         if lenient_issubclass(inferred.type_, fields[var_name].type_):
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pydantic/v1/fields.py:504, in ModelField.infer(cls, name, value, annotation, class_validators, config)
#     501     required = False
#     502 annotation = get_annotation_from_field_info(annotation, field_info, name, config.validate_assignment)
# --> 504 return cls(
#     505     name=name,
#     506     type_=annotation,
#     507     alias=field_info.alias,
#     508     class_validators=class_validators,
#     509     default=value,
#     510     default_factory=field_info.default_factory,
#     511     required=required,
#     512     model_config=config,
#     513     field_info=field_info,
#     514 )
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pydantic/v1/fields.py:434, in ModelField.__init__(self, name, type_, class_validators, model_config, default, default_factory, required, final, alias, field_info)
#     432 self.shape: int = SHAPE_SINGLETON
#     433 self.model_config.prepare_field(self)
# --> 434 self.prepare()
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pydantic/v1/fields.py:544, in ModelField.prepare(self)
#     537 def prepare(self) -> None:
#     538     """
#     539     Prepare the field but inspecting self.default, self.type_ etc.
#     540
#     541     Note: this method is **not** idempotent (because _type_analysis is not idempotent),
#     542     e.g. calling it it multiple times may modify the field and configure it incorrectly.
#     543     """
# --> 544     self._set_default_and_type()
#     545     if self.type_.__class__ is ForwardRef or self.type_.__class__ is DeferredType:
#     546         # self.type_ is currently a ForwardRef and there's nothing we can do now,
#     547         # user will need to call model.update_forward_refs()
#     548         return
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pydantic/v1/fields.py:576, in ModelField._set_default_and_type(self)
#     573     self.annotation = self.type_
#     575 if self.type_ is Undefined:
# --> 576     raise errors_.ConfigError(f'unable to infer type for attribute "{self.name}"')
#     578 if self.required is False and default_value is None:
#     579     self.allow_none = True
#
# ConfigError: unable to infer type for attribute "REGEX"
